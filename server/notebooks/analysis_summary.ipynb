# %%
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('data/transaction_summary.csv')
df['property_type'].unique()
# Out:
# array(['Non-Landed', 'Strata-Landed', 'Landed', 'Exec Condo',
#        'Strata-Landed / Non-Landed', 'Landed / Non-Landed'], dtype=object)

# %%
df_non_landed = df[df['property_type'] == 'Non-Landed']
df_non_landed.sort_values(['reference_period'], ascending=False)
# df_non_landed.groupby([''])
# Out:
#                    project_name           street_name  \
# 52812       WILSHIRE RESIDENCES           FARRER ROAD
# 52717               LATTICE ONE       SERAYA CRESCENT
# 52701  GRANDEUR PARK RESIDENCES  BEDOK SOUTH AVENUE 3
# 52702               GRANGE 1866           GRANGE ROAD
# 52703             HAUS ON HANDY            HANDY ROAD
# ...                         ...                   ...
# 221           SUNSHINE GRANDEUR  LORONG K TELOK KURAU
# 219                   SUN CREST    ST. MICHAEL'S ROAD
# 217             SUITES @ SURREY           SURREY ROAD
# 216          SUITES @ CAIRNHILL          ANTHONY ROAD
# 0                      38 AMBER            AMBER ROAD
#
#                             developer property_type locality  \
# 52812                TE2KS-RH Pte Ltd    Non-Landed      CCR
# 52717      Amcorp Development Pte Ltd    Non-Landed      OCR
# 52701              CEL-Changi Pte Ltd    Non-Landed      OCR
# 52702             Grange 1866 Pte Ltd    Non-Landed      CCR
# ...

# %%
condo_name = 'MIDWOOD'

df[df['project_name'].str.contains(condo_name)].sort_values('reference_period', ascending=False)
# Out:
#       project_name    street_name                          developer  \
# 52730      MIDWOOD  HILLVIEW RISE  Hillview Rise Development Pte Ltd
# 52579      MIDWOOD  HILLVIEW RISE  Hillview Rise Development Pte Ltd
# 52429      MIDWOOD  HILLVIEW RISE  Hillview Rise Development Pte Ltd
# 52277      MIDWOOD  HILLVIEW RISE  Hillview Rise Development Pte Ltd
# 52124      MIDWOOD  HILLVIEW RISE  Hillview Rise Development Pte Ltd
# 51969      MIDWOOD  HILLVIEW RISE  Hillview Rise Development Pte Ltd
# 51816      MIDWOOD  HILLVIEW RISE  Hillview Rise Development Pte Ltd
# 51662      MIDWOOD  HILLVIEW RISE  Hillview Rise Development Pte Ltd
# 51506      MIDWOOD  HILLVIEW RISE  Hillview Rise Development Pte Ltd
# 51356      MIDWOOD  HILLVIEW RISE  Hillview Rise Development Pte Ltd
# 51204      MIDWOOD  HILLVIEW RISE  Hillview Rise Development Pte Ltd
# 51058      MIDWOOD  HILLVIEW RISE  Hillview Rise Development Pte Ltd
# 50914      MIDWOOD  HILLVIEW RISE  Hillview Rise Development Pte Ltd
# ...

# %%
df[df['project_name'].str.contains('PARC CLEMATIS')].sort_values('reference_period', ascending=False)
# Out:
#         project_name    street_name                developer property_type  \
# 52595  PARC CLEMATIS  JALAN LEMPENG  Sing-Haiyi Gold Pte Ltd    Non-Landed
# 52444  PARC CLEMATIS  JALAN LEMPENG  Sing-Haiyi Gold Pte Ltd    Non-Landed
# 52292  PARC CLEMATIS  JALAN LEMPENG  Sing-Haiyi Gold Pte Ltd    Non-Landed
# 52140  PARC CLEMATIS  JALAN LEMPENG  Sing-Haiyi Gold Pte Ltd    Non-Landed
# 51986  PARC CLEMATIS  JALAN LEMPENG  Sing-Haiyi Gold Pte Ltd    Non-Landed
# 51833  PARC CLEMATIS  JALAN LEMPENG  Sing-Haiyi Gold Pte Ltd    Non-Landed
# 51680  PARC CLEMATIS  JALAN LEMPENG  Sing-Haiyi Gold Pte Ltd    Non-Landed
# 51524  PARC CLEMATIS  JALAN LEMPENG  Sing-Haiyi Gold Pte Ltd    Non-Landed
# 51370  PARC CLEMATIS  JALAN LEMPENG  Sing-Haiyi Gold Pte Ltd    Non-Landed
# 51218  PARC CLEMATIS  JALAN LEMPENG  Sing-Haiyi Gold Pte Ltd    Non-Landed
# 51071  PARC CLEMATIS  JALAN LEMPENG  Sing-Haiyi Gold Pte Ltd    Non-Landed
# ...

# %%
df[df['reference_period'] == '2020-02-29'].sort_values('units_sold_month', ascending=False).head(10)
# Out:
#                 project_name           street_name  \
# 51880                  THE M           MIDDLE ROAD
# 51830          PARC CANBERRA         CANBERRA WALK
# 51887   TREASURE AT TAMPINES         TAMPINES LANE
# 51832              PARC ESTA           SIMS AVENUE
# 51792              JADESCAPE           SHUNFU ROAD
# 51829          PARC BOTANNIA       FERNVALE STREET
# 51831          PARC CLEMATIS         JALAN LEMPENG
# 51895         VIEW AT KISMIS         LORONG KISMIS
# 51873  THE GARDEN RESIDENCES  SERANGOON NORTH VIEW
# 51842         PIERMONT GRAND           SUMANG WALK
#
#                                  developer property_type locality  \
# 51880         Wingcharm Investment Pte Ltd    Non-Landed      CCR
# 51830      Hoi Hup Sunway Canberra Pte Ltd    Exec Condo      OCR
# 51887          Sim Lian (Treasure) Pte Ltd    Non-Landed      OCR
# 51832        MCL Land (Everbright) Pte Ltd    Non-Landed      RCR
# 51792  Qingjian Realty (Marymount) Pte Ltd    Non-Landed      RCR
# ...
