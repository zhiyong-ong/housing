# %%
import pandas as pd

# pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('data/ac_01.csv')

# %%
df.sort_values(['Price  ($)'])
# df.columns
# Out:
#               Project Name       Street Name         Type  Postal District  \
# 591  PEOPLE'S PARK COMPLEX         PARK ROAD    Apartment                1
# 671  PEOPLE'S PARK COMPLEX         PARK ROAD    Apartment                1
# 571  PEOPLE'S PARK COMPLEX         PARK ROAD    Apartment                1
# 124  PEOPLE'S PARK COMPLEX         PARK ROAD    Apartment                1
# 18   PEOPLE'S PARK COMPLEX         PARK ROAD    Apartment                1
# ..                     ...               ...          ...              ...
# 612  MARINA BAY RESIDENCES  MARINA BOULEVARD  Condominium                1
# 34   MARINA ONE RESIDENCES        MARINA WAY    Apartment                1
# 373  MARINA BAY RESIDENCES  MARINA BOULEVARD  Condominium                1
# 250           V ON SHENTON       SHENTON WAY    Apartment                1
# 376  MARINA ONE RESIDENCES        MARINA WAY    Apartment                1
#
# ...

# %%
df.loc[:, 'rtest'] = 1
df
# Out:
#                        Project Name       Street Name       Type  \
# 0             MARINA ONE RESIDENCES        MARINA WAY  Apartment
# 1                      V ON SHENTON       SHENTON WAY  Apartment
# 2             MARINA ONE RESIDENCES        MARINA WAY  Apartment
# 3             MARINA ONE RESIDENCES        MARINA WAY  Apartment
# 4                       ONE SHENTON       SHENTON WAY  Apartment
# ...                             ...               ...        ...
# 679           THE SAIL @ MARINA BAY  MARINA BOULEVARD  Apartment
# 680                    V ON SHENTON       SHENTON WAY  Apartment
# 681                    V ON SHENTON       SHENTON WAY  Apartment
# test                              3                 3          3
# Project Name                      3                 3          3
#
#               Postal District Market Segment  \
# 0                           1            CCR
# 1                           1            CCR
# 2                           1            CCR
# ...

# %%
df['Project Name']
# Out:
# 0      MARINA ONE RESIDENCES
# 1               V ON SHENTON
# 2      MARINA ONE RESIDENCES
# 3      MARINA ONE RESIDENCES
# 4                ONE SHENTON
#                ...
# 677           EMERALD GARDEN
# 678             V ON SHENTON
# 679    THE SAIL @ MARINA BAY
# 680             V ON SHENTON
# 681             V ON SHENTON
# Name: Project Name, Length: 682, dtype: object
