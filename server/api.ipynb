# %%
import requests
from secret import ACCESS_KEY
import pandas as pd
from collections import defaultdict
from datetime import datetime
import calendar

pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %% [markdown]
# ### This is the API call for "Private Residential Property Transactions"

# %%
headers = {
    "AccessKey": ACCESS_KEY
}
resp = requests.get('https://www.ura.gov.sg/uraDataService/insertNewToken.action', headers=headers)
token = resp.json()['Result']
token
# Out:
# '8+6Xax@2KAK8xyd9d94fd66btwU6610EZ1b8jt78p7fr1Q1MdsY6v2186nV@9Ft7bJ7--02aeweff7t071-NfY0sbNH2dmSE2t7-'

# %%
headers = {
    'AccessKey': ACCESS_KEY,
    'Token': token
}
params = {
    'service': 'PMI_Resi_Transaction',
    'batch': 3,
}
resp = requests.get('https://www.ura.gov.sg/uraDataService/invokeUraDS', headers=headers, params=params)
resp
# Out:
# <Response [200]>

# %%
def convert_str_to_date(input_str):
    """ converting dates of 0220 for example to 29-02-2020"""
    dt = datetime.strptime(input_str, '%m%y')
    last_day = calendar.monthrange(dt.year, dt.month)[1]
    dt = dt.replace(day=last_day)
    return dt.strftime('%Y-%m-%d')

def map_type_of_sale(type_of_sale_val):
    mapping = {
        '1': 'New Sale',
        '2': 'Sub Sale',
        '3': 'Resale'
    }
    return mapping.get(type_of_sale_val)

res = defaultdict(list)
df = pd.DataFrame()
for item in resp.json()['Result']:
    for trans in item['transaction']:
        res['y'].append(round(float(item['y']), 12) if item.get('y') else None)
        res['x'].append(round(float(item['x']), 12) if item.get('x') else None)
        res['street'].append(item['street'])
        res['project'].append(item['project'])

        res['market_segment'].append(item['marketSegment'])
        
        area = float(trans['area'])
        area_sqft = area * 10.76391042
        res['area_sqm'].append(area)
        res['area_sqft'].append(area_sqft)
        
        res['price'].append(float(trans['price']))
        res['nett_price'].append(float(trans['nettPrice']) if trans.get('nettPrice') else None)
        
        res['unit_price_psm'].append(float(trans['price']) / area)
        res['unit_price_psf'].append(float(trans['price']) / area_sqft)
        
        res['floor_range'].append(trans['floorRange'])
        res['num_units'].append(float(trans['noOfUnits']))
        res['reference_period'].append(convert_str_to_date(trans['contractDate']))
        res['type_of_sale'].append(map_type_of_sale(trans['typeOfSale']))
        res['property_type'].append(trans['propertyType'])
        res['district'].append(int(trans['district']))
        res['type_of_area'].append(trans['typeOfArea'])
        res['tenure'].append(trans['tenure'])
df = df.append(pd.DataFrame(res))
df
# Out:
#                   y             x         street                   project  \
# 0      32612.843992  38874.764492    ELLIOT ROAD  ELLIOT AT THE EAST COAST
# 1      32612.843992  38874.764492    ELLIOT ROAD  ELLIOT AT THE EAST COAST
# 2      32612.843992  38874.764492    ELLIOT ROAD  ELLIOT AT THE EAST COAST
# 3      32612.843992  38874.764492    ELLIOT ROAD  ELLIOT AT THE EAST COAST
# 4      32612.843992  38874.764492    ELLIOT ROAD  ELLIOT AT THE EAST COAST
# ...             ...           ...            ...                       ...
# 28800  42560.406000  35969.634000  PUNGGOL FIELD                     PRIVE
# 28801  42560.406000  35969.634000  PUNGGOL FIELD                     PRIVE
# 28802  42560.406000  35969.634000  PUNGGOL FIELD                     PRIVE
# 28803  42560.406000  35969.634000  PUNGGOL FIELD                     PRIVE
# 28804  42560.406000  35969.634000  PUNGGOL FIELD                     PRIVE
#
#       market_segment  area_sqm    area_sqft      price  nett_price  \
# 0                OCR     122.0  1313.197071  1880000.0         NaN
# 1                OCR     137.0  1474.655728  1900000.0         NaN
# 2                OCR     199.0  2142.018174  2450000.0         NaN
# 3                OCR     161.0  1732.989578  2050000.0         NaN
# 4                OCR      47.0   505.903790   800000.0         NaN
# ...              ...       ...          ...        ...         ...
# 28800            OCR      98.0  1054.863221  1080000.0         NaN
# 28801            OCR     102.0  1097.918863  1080000.0         NaN
# 28802            OCR     102.0  1097.918863  1065000.0         NaN
# 28803            OCR     102.0  1097.918863  1058888.0         NaN
# 28804            OCR      82.0   882.640654   865000.0         NaN
#
#        unit_price_psm  unit_price_psf floor_range  num_units reference_period  \
# 0        15409.836066     1431.620616       01-05        1.0       2019-04-30
# 1        13868.613139     1288.436321       01-05        1.0       2017-08-31
# 2        12311.557789     1143.781145       01-05        1.0       2018-09-30
# 3        12732.919255     1182.926906       01-05        1.0       2017-08-31
# 4        17021.276596     1581.328340       01-05        1.0       2018-12-31
# ...               ...             ...         ...        ...              ...
# 28800    11020.408163     1023.829420       06-10        1.0       2019-10-31
# 28801    10588.235294      983.679247       11-15        1.0       2018-08-31
# 28802    10441.176471      970.017035       11-15        1.0       2018-07-31
# 28803    10381.254902      964.450139       11-15        1.0       2018-08-31
# 28804    10548.780488      980.013775       16-20        1.0       2018-11-30
#
#       type_of_sale          property_type  district type_of_area  \
# 0           Resale            Condominium        15       Strata
# 1           Resale            Condominium        15       Strata
# 2           Resale            Condominium        15       Strata
# 3           Resale            Condominium        15       Strata
# 4           Resale            Condominium        15       Strata
# ...            ...                    ...       ...          ...
# 28800       Resale  Executive Condominium        19       Strata
# 28801       Resale  Executive Condominium        19       Strata
# 28802       Resale  Executive Condominium        19       Strata
# 28803       Resale  Executive Condominium        19       Strata
# 28804       Resale  Executive Condominium        19       Strata
#
#                                   tenure
# 0                               Freehold
# 1                               Freehold
# 2                               Freehold
# 3                               Freehold
# 4                               Freehold
# ...                                  ...
# 28800  99 yrs lease commencing from 2010
# 28801  99 yrs lease commencing from 2010
# 28802  99 yrs lease commencing from 2010
# 28803  99 yrs lease commencing from 2010
# 28804  99 yrs lease commencing from 2010
#
# [28805 rows x 19 columns]

# %%
df1 = pd.read_csv('data/private_prop_transactions/total_transactions.csv', float_precision='round_trip')
# df1 = df1.drop_duplicates(ignore_index=True)
x = df1.sort_values(['project', 'reference_period', 'area_sqft']).iloc[[0]].reset_index(drop=True)
y = df1.sort_values(['project', 'reference_period', 'area_sqft']).iloc[[1]].reset_index(drop=True)

df1[df1.duplicated(subset=['street', 'project', 'market_segment', 'area_sqm', 'price', 'nett_price', 'floor_range', 'num_units', 'reference_period', 'type_of_sale', 'property_type', 'district', 'type_of_area', 'tenure'], keep=False)]
# assert_frame_equal(x, y, check_exact=True, check_index_type=True, check_datetimelike_compat=True, check_categorical=True)
# df1.drop_duplicates(subset=['street', 'project', 'market_segment', 'area_sqm', 'price', 'floor_range', 'num_units', 'reference_period', 'type_of_sale', 'property_type', 'district', 'type_of_area', 'tenure'])
# Out:
# Empty DataFrame
# Columns: [y, x, street, project, market_segment, area_sqm, area_sqft, price, nett_price, unit_price_psm, unit_price_psf, floor_range, num_units, reference_period, type_of_sale, property_type, district, type_of_area, tenure]
# Index: []

# %%
df2 = df1.append(df)
df3 = df2.drop_duplicates(subset=['street', 'project', 'market_segment', 'area_sqm', 'price', 'floor_range', 'num_units', 'reference_period', 'type_of_sale', 'property_type', 'district', 'type_of_area', 'tenure'], ignore_index=True)
# x = df3[df3['project'] == 'ZEPHYR PARK'].sort_values(['reference_period', 'area_sqft']).iloc[[0]].reset_index(drop=True)
# y = df3[df3['project'] == 'ZEPHYR PARK'].sort_values(['reference_period', 'area_sqft']).iloc[[1]].reset_index(drop=True)
# df3[df3['project'] == 'ELLIOT AT THE EAST COAST'].sort_values(['reference_period', 'area_sqft'])
from pandas._testing import assert_frame_equal
assert_frame_equal(x,y)
# df3[df3['project'] == 'ZEPHYR PARK'].sort_values(['reference_period', 'area_sqft'])
# df3.sort_values(['project', 'reference_period', 'area_sqft'])

# assert_frame_equal(x,y, check_exact=True)
df3
# Out:
#                   y             x         street                     project  \
# 0      29491.915576  22726.561999   ZEHNDER ROAD  LANDED HOUSING DEVELOPMENT
# 1      29491.915576  22726.561999   ZEHNDER ROAD  LANDED HOUSING DEVELOPMENT
# 2      29491.915576  22726.561999   ZEHNDER ROAD  LANDED HOUSING DEVELOPMENT
# 3      25005.804519  28384.068816     COVE DRIVE                   TURQUOISE
# 4      25005.804519  28384.068816     COVE DRIVE                   TURQUOISE
# ...             ...           ...            ...                         ...
# 67394  45396.257688  27100.634621  GOODLINK PARK               GOODLINK PARK
# 67395  32699.327274  36157.514620  LORONG NANGKA  LANDED HOUSING DEVELOPMENT
# 67396  36761.646727  29104.810081    CLOVER RISE  LANDED HOUSING DEVELOPMENT
# 67397  32671.914414  34973.777626      IPOH LANE                 EMERY POINT
# 67398  39012.309496  34660.152380    JALAN NAUNG                 SILVER HILL
#
#       market_segment  area_sqm    area_sqft      price  nett_price  \
# 0                RCR     314.0  3379.867872  4750000.0         NaN
# 1                RCR     308.0  3315.284409  5000000.0         NaN
# 2                RCR     524.3  5643.518233  5500000.0         NaN
# 3                CCR     348.0  3745.840826  4400000.0         NaN
# 4                CCR     224.0  2411.115934  3600000.0         NaN
# ...              ...       ...          ...        ...         ...
# 67394            OCR     268.2  2886.880775  2480000.0         NaN
# 67395            RCR     184.4  1984.865081  2750000.0         NaN
# 67396            RCR     167.4  1801.878604  2480000.0         NaN
# 67397            RCR     121.0  1302.433161   725000.0         NaN
# 67398            OCR     152.7  1643.649121  2050000.0         NaN
#
#        unit_price_psm  unit_price_psf floor_range  num_units reference_period  \
# 0        15127.388535     1405.380382           -        1.0       2018-06-30
# 1        16233.766234     1508.166233           -        1.0       2018-09-30
# 2        10490.177379      974.569368           -        1.0       2020-02-29
# 3        12643.678161     1174.636138       06-10        1.0       2018-09-30
# 4        16071.428571     1493.084571       01-05        1.0       2018-03-31
# ...               ...             ...         ...        ...              ...
# 67394     9246.830723      859.058684           -        1.0       2017-10-31
# 67395    14913.232104     1385.484598           -        1.0       2017-08-31
# 67396    14814.814815     1376.341333           -        1.0       2017-08-31
# 67397     5991.735537      556.650446       01-05        1.0       2017-07-31
# 67398    13425.016372     1247.224833           -        1.0       2017-08-31
#
#       type_of_sale  property_type  district type_of_area  \
# 0           Resale  Semi-detached         5         Land
# 1           Resale  Semi-detached         5         Land
# 2           Resale  Semi-detached         5         Land
# 3           Resale    Condominium         4       Strata
# 4           Resale    Condominium         4       Strata
# ...            ...            ...       ...          ...
# 67394       Resale        Terrace        27         Land
# 67395       Resale        Terrace        15         Land
# 67396       Resale        Terrace        20         Land
# 67397       Resale      Apartment        15       Strata
# 67398       Resale        Terrace        19         Land
#
#                                   tenure
# 0                               Freehold
# 1                               Freehold
# 2                               Freehold
# 3      99 yrs lease commencing from 2007
# 4      99 yrs lease commencing from 2007
# ...                                  ...
# 67394                           Freehold
# 67395                                 NA
# 67396                                 NA
# 67397                                 NA
# 67398                                 NA
#
# [67399 rows x 19 columns]

# %%
# df['property_type'].unique()
df3[df3['project'] == 'ZEPHYR PARK'].sort_values(['reference_period', 'area_sqft']).iloc[[0, 1]]
# Out:
#                   y            x           street      project market_segment  \
# 36734  35592.978832  41180.67381  SEA BREEZE ROAD  ZEPHYR PARK            OCR
# 74075  35592.978832  41180.67381  SEA BREEZE ROAD  ZEPHYR PARK            OCR
#
#        area_sqm    area_sqft      price  nett_price  unit_price_psm  \
# 36734     269.6  2901.950249  2980000.0         NaN    11053.412463
# 74075     269.6  2901.950249  2980000.0         NaN    11053.412463
#
#        unit_price_psf floor_range  num_units reference_period type_of_sale  \
# 36734      1026.89562           -        1.0       2017-11-30       Resale
# 74075      1026.89562           -        1.0       2017-11-30       Resale
#
#       property_type  district type_of_area    tenure
# 36734       Terrace        16         Land  Freehold
# 74075       Terrace        16         Land  Freehold

# %%
assert x.at[0, 'type_of_sale'] == y.at[0, 'type_of_sale']

# %%
x.at[0, 'x']
# x.dtypes
# Out:
# 41180.673810069995

# %%
y.at[0, 'x']
# y.dtypes
# Out:
# 41180.673810069995

# %%
a = pd.DataFrame({'a': ['1', '2'], 'b': ['3', '4']})
a.at[0, 'a']
# Out:
# '1'

# %%
'%.20f' % df[df['project'] == 'ZEPHYR PARK'].at[7959, 'x'], 12
# Out:
# ('41180.67381006999494275078', 12)

# %%
df1 = pd.read_csv('data/private_prop_transactions/total_transactions.csv')
df1.sort_values('observation_time')
# Out:
#                   y             x             street  \
# 0      29491.915576  22726.561999       ZEHNDER ROAD
# 44929  41198.909000  35025.430100   COMPASSVALE ROAD
# 44930  41198.909000  35025.430100   COMPASSVALE ROAD
# 44931  41198.909000  35025.430100   COMPASSVALE ROAD
# 44932  41198.909000  35025.430100   COMPASSVALE ROAD
# ...             ...           ...                ...
# 67407  32671.914414  34973.777626          IPOH LANE
# 67404  30747.253000  27457.193100  RIVER VALLEY ROAD
# 67405  32699.327274  36157.514620      LORONG NANGKA
# 67406  36761.646727  29104.810081        CLOVER RISE
# 67408  39012.309496  34660.152380        JALAN NAUNG
#
#                           project market_segment  area_sqm    area_sqft  \
# 0      LANDED HOUSING DEVELOPMENT            RCR     314.0  3379.867872
# 44929                 THE LUXURIE            OCR      98.0  1054.863221
# 44930                 THE LUXURIE            OCR      87.0   936.460207
# 44931                 THE LUXURIE            OCR      72.0   775.001550
# 44932                 THE LUXURIE            OCR      42.0   452.084238
# ...                           ...            ...       ...          ...
# 67407                 EMERY POINT            RCR     121.0  1302.433161
# 67404               RV RESIDENCES            CCR      63.0   678.126356
# 67405  LANDED HOUSING DEVELOPMENT            RCR     184.4  1984.865081
# 67406  LANDED HOUSING DEVELOPMENT            RCR     167.4  1801.878604
# 67408                 SILVER HILL            OCR     152.7  1643.649121
#
#            price  nett_price  unit_price_psm  unit_price_psf floor_range  \
# 0      4750000.0         NaN    15127.388535     1405.380382           -
# 44929  1230000.0         NaN    12551.020408     1166.027951       06-10
# 44930   913000.0         NaN    10494.252874      974.947994       11-15
# 44931   930000.0         NaN    12916.666667     1199.997600       06-10
# 44932   668000.0         NaN    15904.761905     1477.600731       06-10
# ...          ...         ...             ...             ...         ...
# 67407   725000.0         NaN     5991.735537      556.650446       01-05
# 67404  1355820.0         NaN    21520.952381     1999.361899       06-10
# 67405  2750000.0         NaN    14913.232104     1385.484598           -
# 67406  2480000.0         NaN    14814.814815     1376.341333           -
# 67408  2050000.0         NaN    13425.016372     1247.224833           -
#
#        num_units reference_period type_of_sale  property_type  district  \
# 0              1       2018-06-30       Resale  Semi-detached         5
# 44929          1       2017-05-31       Resale    Condominium        19
# 44930          1       2018-03-31       Resale    Condominium        19
# 44931          1       2019-04-30       Resale    Condominium        19
# 44932          1       2019-11-30       Resale    Condominium        19
# ...          ...              ...          ...            ...       ...
# 67407          1       2017-07-31       Resale      Apartment        15
# 67404          1       2017-08-31       Resale    Condominium        10
# 67405          1       2017-08-31       Resale        Terrace        15
# 67406          1       2017-08-31       Resale        Terrace        20
# 67408          1       2017-08-31       Resale        Terrace        19
#
#       type_of_area                             tenure  \
# 0             Land                           Freehold
# 44929       Strata  99 yrs lease commencing from 2011
# 44930       Strata  99 yrs lease commencing from 2011
# 44931       Strata  99 yrs lease commencing from 2011
# 44932       Strata  99 yrs lease commencing from 2011
# ...            ...                                ...
# 67407       Strata                                NaN
# 67404       Strata                                NaN
# 67405         Land                                NaN
# 67406         Land                                NaN
# 67408         Land                                NaN
#
#                  observation_time
# 0      2020-04-10 23:05:10.582581
# 44929  2020-04-10 23:05:10.582581
# 44930  2020-04-10 23:05:10.582581
# 44931  2020-04-10 23:05:10.582581
# 44932  2020-04-10 23:05:10.582581
# ...                           ...
# 67407  2020-04-10 23:05:38.144093
# 67404  2020-04-10 23:05:38.144093
# 67405  2020-04-10 23:05:38.144093
# 67406  2020-04-10 23:05:38.144093
# 67408  2020-04-10 23:05:38.144093
#
# [67409 rows x 20 columns]

# %%
df1[df1['project'] == 'SILVER HILL'].sort_values(['reference_period', 'price'])
# Out:
#                   y            x       street      project market_segment  \
# 54078  39012.309496  34660.15238  JALAN NAUNG  SILVER HILL            OCR
# 54079  39012.309496  34660.15238  JALAN NAUNG  SILVER HILL            OCR
# 67408  39012.309496  34660.15238  JALAN NAUNG  SILVER HILL            OCR
#
#        area_sqm    area_sqft      price  nett_price  unit_price_psm  \
# 54078     261.0  2809.380620  2680000.0         NaN    10268.199234
# 54079     152.7  1643.649121  2050000.0         NaN    13425.016372
# 67408     152.7  1643.649121  2050000.0         NaN    13425.016372
#
#        unit_price_psf floor_range  num_units reference_period type_of_sale  \
# 54078      953.946924           -          1       2017-05-31       Resale
# 54079     1247.224833           -          1       2017-08-31       Resale
# 67408     1247.224833           -          1       2017-08-31       Resale
#
#       property_type  district type_of_area  \
# 54078       Terrace        19         Land
# 54079       Terrace        19         Land
# 67408       Terrace        19         Land
#
#                                    tenure            observation_time
# 54078  945 yrs lease commencing from 1936  2020-04-10 23:05:10.582581
# 54079                                 NaN  2020-04-10 23:05:10.582581
# 67408                                 NaN  2020-04-10 23:05:38.144093

# %%
x = df1[df1['project'] == 'SILVER HILL'].sort_values(['reference_period', 'price']).iloc[[1]].reset_index(drop=True).drop(columns='observation_time')
y = df1[df1['project'] == 'SILVER HILL'].sort_values(['reference_period', 'price']).iloc[[2]].reset_index(drop=True).drop(columns='observation_time')
assert_frame_equal(x, y, check_exact=True, check_index_type=True, check_datetimelike_compat=True, check_categorical=True)

# %%
y['tenure']
# Out:
# 0    NaN
# Name: tenure, dtype: object

# %%
df[df['project'] == 'SILVER HILL']
# Out:
#                   y            x       street      project market_segment  \
# 26463  39012.309496  34660.15238  JALAN NAUNG  SILVER HILL            OCR
# 26464  39012.309496  34660.15238  JALAN NAUNG  SILVER HILL            OCR
#
#        area_sqm    area_sqft      price  nett_price  unit_price_psm  \
# 26463     261.0  2809.380620  2680000.0         NaN    10268.199234
# 26464     152.7  1643.649121  2050000.0         NaN    13425.016372
#
#        unit_price_psf floor_range  num_units reference_period type_of_sale  \
# 26463      953.946924           -        1.0       2017-05-31       Resale
# 26464     1247.224833           -        1.0       2017-08-31       Resale
#
#       property_type  district type_of_area                              tenure
# 26463       Terrace        19         Land  945 yrs lease commencing from 1936
# 26464       Terrace        19         Land                                  NA

# %%
# for item  in resp.json()['Result']:
#     if item['project'] == 'SILVER HILL':
#         a1 = item
# a1['transaction'][1]
df['tenure'][26464]
# Out:
# 'NA'

# %%
# pd.DataFrame({'a': []})
subset_cols = ['street', 'project', 'market_segment', 'area_sqm', 'price', 'nett_price', 'floor_range', 'num_units',
               'reference_period', 'type_of_sale', 'property_type', 'district', 'type_of_area', 'tenure']
df11 = df.drop_duplicates(subset=subset_cols)
df11.to_csv('test.csv', index=False)

# %%
df1 = pd.read_csv('data/private_prop_transactions/total_transactions.csv')
df1[df1['project'] == 'SILVER HILL']
# Out:
#                   y            x       street      project market_segment  \
# 54078  39012.309496  34660.15238  JALAN NAUNG  SILVER HILL            OCR
# 54079  39012.309496  34660.15238  JALAN NAUNG  SILVER HILL            OCR
#
#        area_sqm    area_sqft      price  nett_price  unit_price_psm  \
# 54078     261.0  2809.380620  2680000.0         NaN    10268.199234
# 54079     152.7  1643.649121  2050000.0         NaN    13425.016372
#
#        unit_price_psf floor_range  num_units reference_period type_of_sale  \
# 54078      953.946924           -          1       2017-05-31       Resale
# 54079     1247.224833           -          1       2017-08-31       Resale
#
#       property_type  district type_of_area  \
# 54078       Terrace        19         Land
# 54079       Terrace        19         Land
#
#                                    tenure            observation_time
# 54078  945 yrs lease commencing from 1936  2020-04-10 23:24:18.892924
# 54079                                 NaN  2020-04-10 23:24:18.892924

# %% [markdown]
# ### This is the API call for "Private Residential Property Units Sold by Developers"

# %%
headers = {
    "AccessKey": ACCESS_KEY
}
resp = requests.get('https://www.ura.gov.sg/uraDataService/insertNewToken.action', headers=headers)
token = resp.json()['Result']

headers = {
    'AccessKey': ACCESS_KEY,
    'Token': token
}
params = {
    'service': 'PMI_Resi_Developer_Sales',
    'refPeriod': '1019',
}
resp = requests.get('https://www.ura.gov.sg/uraDataService/invokeUraDS', headers=headers, params=params)
resp
# Out:
# <Response [200]>

# %%
resp.json()
# Out:
# {'Status': 'Success',
#  'Result': [{'street': 'EAST COAST AVENUE',
#    'district': '15',
#    'propertyType': 'Landed',
#    'project': 'CAYMAN RESIDENCES',
#    'developer': 'Pinnacle Homes (East Coast) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2495,
#      'highestPrice': 2606,
#      'lowestPrice': 2409,
#      'launchedToDate': 19,
#      'soldInMonth': 5,
#      'launchedInMonth': 0,
#      'soldToDate': 17,
#      'unitsAvail': 19}],
#    'marketSegment': 'OCR'},
#   {'street': 'SILAT AVENUE',
#    'district': '03',
#    'propertyType': 'Non-Landed',
#    'project': 'AVENUE SOUTH RESIDENCE',
#    'developer': 'United Venture Development (Silat) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1990,
#      'highestPrice': 2225,
#      'lowestPrice': 1802,
#      'launchedToDate': 500,
#      'soldInMonth': 40,
#      'launchedInMonth': 0,
#      'soldToDate': 397,
#      'unitsAvail': 1074}],
#    'marketSegment': 'RCR'},
#   {'street': 'DE SOUZA AVENUE',
#    'district': '21',
#    'propertyType': 'Non-Landed',
#    'project': 'VERDALE',
#    'developer': 'C&C (JJK) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 258}],
#    'marketSegment': 'RCR'},
#   {'street': 'BEDOK SOUTH AVENUE 3',
#    'district': '16',
#    'propertyType': 'Non-Landed',
#    'project': 'GRANDEUR PARK RESIDENCES',
#    'developer': 'CEL-Changi Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1549,
#      'highestPrice': 1549,
#      'lowestPrice': 1549,
#      'launchedToDate': 720,
#      'soldInMonth': 1,
#      'launchedInMonth': 0,
#      'soldToDate': 703,
#      'unitsAvail': 720}],
#    'marketSegment': 'OCR'},
#   {'street': 'HOUGANG AVENUE 2',
#    'district': '19',
#    'propertyType': 'Non-Landed',
#    'project': 'THE FLORENCE RESIDENCES',
#    'developer': 'Florence Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1492,
#      'highestPrice': 1636,
#      'lowestPrice': 1418,
#      'launchedToDate': 550,
#      'soldInMonth': 17,
#      'launchedInMonth': 0,
#      'soldToDate': 523,
#      'unitsAvail': 1410}],
#    'marketSegment': 'OCR'},
#   {'street': 'HOLLAND ROAD / QUEENSWAY / HOLLAND HILL',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'project': 'HYLL ON HOLLAND',
#    'developer': 'FEC Skypark Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 319}],
#    'marketSegment': 'CCR'},
#   {'street': 'HANDY ROAD',
#    'district': '09',
#    'propertyType': 'Non-Landed',
#    'project': 'HAUS ON HANDY',
#    'developer': 'CDL Regulus Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2865,
#      'highestPrice': 2913,
#      'lowestPrice': 2840,
#      'launchedToDate': 30,
#      'soldInMonth': 5,
#      'launchedInMonth': 0,
#      'soldToDate': 29,
#      'unitsAvail': 188}],
#    'marketSegment': 'CCR'},
#   {'street': 'JIAK KIM STREET',
#    'district': '03',
#    'propertyType': 'Non-Landed',
#    'project': 'RIVIERE',
#    'developer': 'Frasers Property Quayside Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2818,
#      'highestPrice': 2886,
#      'lowestPrice': 2750,
#      'launchedToDate': 60,
#      'soldInMonth': 2,
#      'launchedInMonth': 0,
#      'soldToDate': 46,
#      'unitsAvail': 455}],
#    'marketSegment': 'RCR'},
#   {'street': 'AMBER ROAD',
#    'district': '15',
#    'propertyType': 'Non-Landed',
#    'x': '35313.280303159998',
#    'project': 'COASTLINE RESIDENCES',
#    'y': '31306.979704149999',
#    'developer': 'SL Capital (3) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2712,
#      'highestPrice': 2843,
#      'lowestPrice': 2559,
#      'launchedToDate': 144,
#      'soldInMonth': 5,
#      'launchedInMonth': 0,
#      'soldToDate': 25,
#      'unitsAvail': 144}],
#    'marketSegment': 'RCR'},
#   {'street': 'JALAN LEMPENG',
#    'district': '05',
#    'propertyType': 'Non-Landed',
#    'project': 'PARC CLEMATIS',
#    'developer': 'Sing-Haiyi Gold Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1606,
#      'highestPrice': 1697,
#      'lowestPrice': 1041,
#      'launchedToDate': 665,
#      'soldInMonth': 32,
#      'launchedInMonth': 0,
#      'soldToDate': 461,
#      'unitsAvail': 1468}],
#    'marketSegment': 'OCR'},
#   {'street': 'BALMORAL ROAD',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'x': '27765.624210869999',
#    'project': 'THE HYDE',
#    'y': '32955.020255060001',
#    'developer': 'Aurum Land Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2951,
#      'highestPrice': 2951,
#      'lowestPrice': 2951,
#      'launchedToDate': 117,
#      'soldInMonth': 1,
#      'launchedInMonth': 0,
#      'soldToDate': 6,
#      'unitsAvail': 117}],
#    'marketSegment': 'CCR'},
#   {'street': 'LORONG 24 GEYLANG',
#    'district': '14',
#    'propertyType': 'Non-Landed',
#    'x': '33602.495309689997',
#    'project': 'REZI 24',
#    'y': '32664.62806039',
#    'developer': 'Development 24 Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1562,
#      'highestPrice': 1593,
#      'lowestPrice': 1486,
#      'launchedToDate': 110,
#      'soldInMonth': 6,
#      'launchedInMonth': 0,
#      'soldToDate': 34,
#      'unitsAvail': 110}],
#    'marketSegment': 'RCR'},
#   {'street': 'COVE DRIVE',
#    'district': '04',
#    'propertyType': 'Strata-Landed',
#    'x': '28269.0311',
#    'project': 'THE GREEN COLLECTION',
#    'y': '25043.2169',
#    'developer': 'Green Collection Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 20}],
#    'marketSegment': 'CCR'},
#   {'street': 'SIGLAP LINK',
#    'district': '15',
#    'propertyType': 'Non-Landed',
#    'project': 'SEASIDE RESIDENCES',
#    'developer': 'East Vue Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1865,
#      'highestPrice': 1969,
#      'lowestPrice': 1806,
#      'launchedToDate': 841,
#      'soldInMonth': 3,
#      'launchedInMonth': 0,
#      'soldToDate': 768,
#      'unitsAvail': 841}],
#    'marketSegment': 'OCR'},
#   {'street': 'HOLLAND VILLAGE WAY',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'project': 'ONE HOLLAND VILLAGE RESIDENCES',
#    'developer': 'Commons Residential Pte Ltd/Commons SR Trustee Pte Ltd/Commons Commercial Trustee Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 296}],
#    'marketSegment': 'CCR'},
#   {'street': 'HILLVIEW RISE',
#    'district': '23',
#    'propertyType': 'Non-Landed',
#    'project': 'MIDWOOD',
#    'developer': 'Hillview Rise Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1640,
#      'highestPrice': 1748,
#      'lowestPrice': 1555,
#      'launchedToDate': 100,
#      'soldInMonth': 24,
#      'launchedInMonth': 100,
#      'soldToDate': 24,
#      'unitsAvail': 564}],
#    'marketSegment': 'OCR'},
#   {'street': 'ALEXANDRA VIEW',
#    'district': '03',
#    'propertyType': 'Non-Landed',
#    'project': 'ARTRA',
#    'developer': 'FEC Skyline Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1943,
#      'highestPrice': 2123,
#      'lowestPrice': 1830,
#      'launchedToDate': 400,
#      'soldInMonth': 8,
#      'launchedInMonth': 0,
#      'soldToDate': 360,
#      'unitsAvail': 400}],
#    'marketSegment': 'RCR'},
#   {'street': 'MEYER ROAD',
#    'district': '15',
#    'propertyType': 'Non-Landed',
#    'x': '34454.587110420002',
#    'project': 'MEYER MANSION',
#    'y': '31033.754747689998',
#    'developer': 'Meyer Mansion Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2656,
#      'highestPrice': 3142,
#      'lowestPrice': 2535,
#      'launchedToDate': 40,
#      'soldInMonth': 5,
#      'launchedInMonth': 0,
#      'soldToDate': 25,
#      'unitsAvail': 200}],
#    'marketSegment': 'RCR'},
#   {'street': 'MARTIN PLACE',
#    'district': '09',
#    'propertyType': 'Non-Landed',
#    'project': 'MARTIN MODERN',
#    'developer': 'Martin Modern Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2611,
#      'highestPrice': 2879,
#      'lowestPrice': 2516,
#      'launchedToDate': 380,
#      'soldInMonth': 8,
#      'launchedInMonth': 0,
#      'soldToDate': 355,
#      'unitsAvail': 450}],
#    'marketSegment': 'CCR'},
#   {'street': 'EVERTON ROAD',
#    'district': '02',
#    'propertyType': 'Non-Landed',
#    'project': 'SKY EVERTON',
#    'developer': 'SL Capital (6) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2577,
#      'highestPrice': 2866,
#      'lowestPrice': 2295,
#      'launchedToDate': 262,
#      'soldInMonth': 8,
#      'launchedInMonth': 0,
#      'soldToDate': 172,
#      'unitsAvail': 262}],
#    'marketSegment': 'RCR'},
#   {'street': 'TRANSIT ROAD',
#    'district': '26',
#    'propertyType': 'Non-Landed',
#    'x': '26309.982005939999',
#    'project': 'ROOTS @ TRANSIT',
#    'y': '42973.826228380001',
#    'developer': 'Soonbee Investment Holdings Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 6,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 1,
#      'unitsAvail': 31}],
#    'marketSegment': 'OCR'},
#   {'street': 'DALVEY ROAD',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'project': 'DALVEY HAUS',
#    'developer': 'Dalvey Breeze Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 27}],
#    'marketSegment': 'CCR'},
#   {'street': 'JALAN MUTIARA',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'x': '27493.155249139999',
#    'project': 'M5',
#    'y': '30898.898411079999',
#    'developer': 'TTH Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 33,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 11,
#      'unitsAvail': 33}],
#    'marketSegment': 'CCR'},
#   {'street': 'CARPMAEL ROAD',
#    'district': '15',
#    'propertyType': 'Non-Landed',
#    'x': '35165.803291',
#    'project': 'CARPMAEL THIRTY-EIGHT',
#    'y': '32817.60008064',
#    'developer': 'LWH Carpmael Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1524,
#      'highestPrice': 1524,
#      'lowestPrice': 1524,
#      'launchedToDate': 16,
#      'soldInMonth': 1,
#      'launchedInMonth': 0,
#      'soldToDate': 12,
#      'unitsAvail': 16}],
#    'marketSegment': 'RCR'},
#   {'street': 'KANDIS LINK',
#    'district': '27',
#    'propertyType': 'Non-Landed',
#    'project': 'KANDIS RESIDENCE',
#    'developer': 'Dillenia Land Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1279,
#      'highestPrice': 1322,
#      'lowestPrice': 1236,
#      'launchedToDate': 91,
#      'soldInMonth': 2,
#      'launchedInMonth': 0,
#      'soldToDate': 82,
#      'unitsAvail': 130}],
#    'marketSegment': 'OCR'},
#   {'street': 'NASSIM HILL',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'project': '19 NASSIM',
#    'developer': 'Parksville Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 101}],
#    'marketSegment': 'CCR'},
#   {'street': 'INSTITUTION HILL',
#    'district': '09',
#    'propertyType': 'Non-Landed',
#    'x': '28720.483972820001',
#    'project': 'ASPEN LINQ',
#    'y': '30866.29160921',
#    'developer': 'Optimus Hill Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 18,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 17,
#      'unitsAvail': 18}],
#    'marketSegment': 'CCR'},
#   {'street': 'LORNIE ROAD',
#    'district': '11',
#    'propertyType': 'Landed',
#    'project': 'LANDED HOUSING DEVELOPMENT',
#    'developer': 'Wah Khiaw Developments Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 5}],
#    'marketSegment': 'CCR'},
#   {'street': 'CUSCADEN ROAD',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'project': 'CUSCADEN RESERVE',
#    'developer': 'Cuscaden Homes Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 192,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 3,
#      'unitsAvail': 192}],
#    'marketSegment': 'CCR'},
#   {'street': 'MEYAPPA CHETTIAR ROAD',
#    'district': '13',
#    'propertyType': 'Non-Landed',
#    'x': '31930.626233809998',
#    'project': 'THE POIZ RESIDENCES',
#    'y': '34791.143038510001',
#    'developer': 'MCC Land (Potong Pasir) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 731,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 731,
#      'unitsAvail': 731}],
#    'marketSegment': 'RCR'},
#   {'street': 'SANDY LANE',
#    'district': '15',
#    'propertyType': 'Non-Landed',
#    'x': '34673.741732049998',
#    'project': 'SANDY EIGHT',
#    'y': '32700.98082038',
#    'developer': 'JVA Katong Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 20,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 20,
#      'unitsAvail': 20}],
#    'marketSegment': 'RCR'},
#   {'street': 'UPPER THOMSON ROAD',
#    'district': '20',
#    'propertyType': 'Non-Landed',
#    'x': '28232.988499599999',
#    'project': '183 LONGHAUS',
#    'y': '37039.888903100003',
#    'developer': 'TEE Ventures Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 40,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 39,
#      'unitsAvail': 40}],
#    'marketSegment': 'RCR'},
#   {'street': 'PAYA LEBAR CRESCENT',
#    'district': '19',
#    'propertyType': 'Strata-Landed',
#    'x': '33492.9418',
#    'project': 'URBAN VILLAS',
#    'y': '36567.7105',
#    'developer': 'PLC Seven (S) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 7,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 5,
#      'unitsAvail': 7}],
#    'marketSegment': 'OCR'},
#   {'street': 'JALAN KEMAMAN',
#    'district': '12',
#    'propertyType': 'Non-Landed',
#    'x': '30037.79419949',
#    'project': 'NEEM TREE',
#    'y': '34389.412867519998',
#    'developer': 'Aylesbury Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1957,
#      'highestPrice': 1957,
#      'lowestPrice': 1957,
#      'launchedToDate': 84,
#      'soldInMonth': 1,
#      'launchedInMonth': 0,
#      'soldToDate': 73,
#      'unitsAvail': 84}],
#    'marketSegment': 'RCR'},
#   {'street': 'WEST COAST VALE',
#    'district': '05',
#    'propertyType': 'Non-Landed',
#    'project': 'TWIN VEW',
#    'developer': 'CSC Land Group (S) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1503,
#      'highestPrice': 1503,
#      'lowestPrice': 1503,
#      'launchedToDate': 520,
#      'soldInMonth': 1,
#      'launchedInMonth': 0,
#      'soldToDate': 457,
#      'unitsAvail': 520}],
#    'marketSegment': 'OCR'},
#   {'street': 'FERNVALE STREET',
#    'district': '28',
#    'propertyType': 'Non-Landed',
#    'project': 'PARC BOTANNIA',
#    'developer': 'Fernvale Green Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1334,
#      'highestPrice': 1423,
#      'lowestPrice': 1137,
#      'launchedToDate': 735,
#      'soldInMonth': 49,
#      'launchedInMonth': 0,
#      'soldToDate': 663,
#      'unitsAvail': 735}],
#    'marketSegment': 'OCR'},
#   {'street': 'JALAN EUNOS',
#    'district': '14',
#    'propertyType': 'Non-Landed',
#    'x': '36124.919443820003',
#    'project': 'THE NAVIAN',
#    'y': '34456.545213060001',
#    'developer': 'RH Eunos Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 48,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 48,
#      'unitsAvail': 48}],
#    'marketSegment': 'OCR'},
#   {'street': 'BUKIT BATOK STREET 41',
#    'district': '23',
#    'propertyType': 'Non-Landed',
#    'project': 'LE QUEST',
#    'developer': 'Qingjian Realty (BBC) Pte Ltd/Qingjian Realty (BBR) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1414,
#      'highestPrice': 1467,
#      'lowestPrice': 1258,
#      'launchedToDate': 516,
#      'soldInMonth': 4,
#      'launchedInMonth': 0,
#      'soldToDate': 446,
#      'unitsAvail': 516}],
#    'marketSegment': 'OCR'},
#   {'street': 'DAIRY FARM LANE',
#    'district': '23',
#    'propertyType': 'Non-Landed',
#    'project': 'DAIRY FARM RESIDENCES',
#    'developer': 'UE Dairy Farm Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 460}],
#    'marketSegment': 'OCR'},
#   {'street': 'DRAYCOTT PARK',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'project': 'EDEN',
#    'developer': 'Celestial Fortune Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 20}],
#    'marketSegment': 'CCR'},
#   {'street': 'TAMPINES STREET 86',
#    'district': '18',
#    'propertyType': 'Non-Landed',
#    'x': '38687.4197',
#    'project': 'THE ALPS RESIDENCES',
#    'y': '37491.0878',
#    'developer': 'MCC Land (Tampines) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 626,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 621,
#      'unitsAvail': 626}],
#    'marketSegment': 'OCR'},
#   {'street': 'PAYA LEBAR ROAD',
#    'district': '14',
#    'propertyType': 'Non-Landed',
#    'project': 'PARK PLACE RESIDENCES AT PLQ',
#    'developer': 'Roma Central Pte Ltd/Milano Central Pte Ltd/Verona Central Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1742,
#      'highestPrice': 1814,
#      'lowestPrice': 1581,
#      'launchedToDate': 429,
#      'soldInMonth': 3,
#      'launchedInMonth': 0,
#      'soldToDate': 428,
#      'unitsAvail': 429}],
#    'marketSegment': 'RCR'},
#   {'street': 'WOODLANDS VIEW',
#    'district': '25',
#    'propertyType': 'Exec Condo',
#    'x': '25472.7781',
#    'project': 'NORTHWAVE',
#    'y': '47272.2994',
#    'developer': 'Hao Yuan (Woodlands) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 931,
#      'highestPrice': 931,
#      'lowestPrice': 931,
#      'launchedToDate': 358,
#      'soldInMonth': 1,
#      'launchedInMonth': 0,
#      'soldToDate': 358,
#      'unitsAvail': 358}],
#    'marketSegment': 'OCR'},
#   {'street': 'PEARL BANK',
#    'district': '03',
#    'propertyType': 'Non-Landed',
#    'x': '28719.68217439',
#    'project': 'ONE PEARL BANK',
#    'y': '29485.916300739999',
#    'developer': 'Areca Investment Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2467,
#      'highestPrice': 2574,
#      'lowestPrice': 2231,
#      'launchedToDate': 280,
#      'soldInMonth': 7,
#      'launchedInMonth': 0,
#      'soldToDate': 240,
#      'unitsAvail': 774}],
#    'marketSegment': 'RCR'},
#   {'street': 'WEST COAST VALE',
#    'district': '05',
#    'propertyType': 'Non-Landed',
#    'project': 'WHISTLER GRAND',
#    'developer': 'CDL Pegasus Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1455,
#      'highestPrice': 1580,
#      'lowestPrice': 1307,
#      'launchedToDate': 450,
#      'soldInMonth': 18,
#      'launchedInMonth': 0,
#      'soldToDate': 436,
#      'unitsAvail': 716}],
#    'marketSegment': 'OCR'},
#   {'street': 'HOW SUN ROAD',
#    'district': '19',
#    'propertyType': 'Non-Landed',
#    'x': '33283.162719000003',
#    'project': 'THE LILIUM',
#    'y': '36399.143298859997',
#    'developer': 'Singhaiyi Huajiang Amber Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 40,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 2,
#      'unitsAvail': 80}],
#    'marketSegment': 'OCR'},
#   {'street': 'PERUMAL ROAD',
#    'district': '08',
#    'propertyType': 'Non-Landed',
#    'x': '30498.25653815',
#    'project': 'UPTOWN @ FARRER',
#    'y': '32803.506191239998',
#    'developer': 'Perumal Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1854,
#      'highestPrice': 1890,
#      'lowestPrice': 1838,
#      'launchedToDate': 116,
#      'soldInMonth': 5,
#      'launchedInMonth': 0,
#      'soldToDate': 18,
#      'unitsAvail': 116}],
#    'marketSegment': 'RCR'},
#   {'street': 'SERAYA CRESCENT',
#    'district': '20',
#    'propertyType': 'Non-Landed',
#    'project': 'LATTICE ONE',
#    'developer': 'TEE Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 48,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 27,
#      'unitsAvail': 48}],
#    'marketSegment': 'OCR'},
#   {'street': 'EAST COAST ROAD',
#    'district': '15',
#    'propertyType': 'Non-Landed',
#    'x': '36677.316184029997',
#    'project': 'INFINI AT EAST COAST',
#    'y': '32389.122661689999',
#    'developer': 'GDL Land Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1908,
#      'highestPrice': 1908,
#      'lowestPrice': 1908,
#      'launchedToDate': 36,
#      'soldInMonth': 1,
#      'launchedInMonth': 0,
#      'soldToDate': 2,
#      'unitsAvail': 36}],
#    'marketSegment': 'OCR'},
#   {'street': 'GILSTEAD ROAD',
#    'district': '11',
#    'propertyType': 'Non-Landed',
#    'x': '28546.403139269999',
#    'project': '35 GILSTEAD',
#    'y': '33311.60441179',
#    'developer': 'TEE Forward Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2498,
#      'highestPrice': 2553,
#      'lowestPrice': 2461,
#      'launchedToDate': 35,
#      'soldInMonth': 3,
#      'launchedInMonth': 0,
#      'soldToDate': 18,
#      'unitsAvail': 70}],
#    'marketSegment': 'CCR'},
#   {'street': 'OUTRAM ROAD',
#    'district': '03',
#    'propertyType': 'Non-Landed',
#    'project': 'RESIDENTIAL APARTMENTS',
#    'developer': 'Outram Realty Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 17}],
#    'marketSegment': 'RCR'},
#   {'street': 'DUNEARN ROAD',
#    'district': '11',
#    'propertyType': 'Non-Landed',
#    'x': '25598.18271589',
#    'project': 'DUNEARN 386',
#    'y': '34096.010181960003',
#    'developer': 'RH Central Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 35,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 3,
#      'unitsAvail': 35}],
#    'marketSegment': 'CCR'},
#   {'street': 'SERAYA LANE',
#    'district': '15',
#    'propertyType': 'Non-Landed',
#    'x': '35411.771162750003',
#    'project': 'SERAYA RESIDENCES',
#    'y': '32078.631180270001',
#    'developer': 'Macly 33 Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 17,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 1,
#      'unitsAvail': 17}],
#    'marketSegment': 'RCR'},
#   {'street': 'FARRER ROAD',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'project': 'WILSHIRE RESIDENCES',
#    'developer': 'TE2KS-RH Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2416,
#      'highestPrice': 2634,
#      'lowestPrice': 2198,
#      'launchedToDate': 20,
#      'soldInMonth': 2,
#      'launchedInMonth': 0,
#      'soldToDate': 8,
#      'unitsAvail': 85}],
#    'marketSegment': 'CCR'},
#   {'street': 'MATTAR ROAD',
#    'district': '14',
#    'propertyType': 'Non-Landed',
#    'project': 'THE ANTARES',
#    'developer': 'FSKH Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1756,
#      'highestPrice': 1756,
#      'lowestPrice': 1745,
#      'launchedToDate': 265,
#      'soldInMonth': 5,
#      'launchedInMonth': 0,
#      'soldToDate': 22,
#      'unitsAvail': 265}],
#    'marketSegment': 'RCR'},
#   {'street': 'TESSENSOHN ROAD',
#    'district': '12',
#    'propertyType': 'Non-Landed',
#    'project': '1953',
#    'developer': 'Oxley Amethyst Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 58,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 30,
#      'unitsAvail': 58}],
#    'marketSegment': 'RCR'},
#   {'street': 'KIM YAM ROAD',
#    'district': '09',
#    'propertyType': 'Non-Landed',
#    'x': '28578.669789440001',
#    'project': 'THE IVERIA',
#    'y': '30860.064951370002',
#    'developer': 'Macly Iveria Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 51}],
#    'marketSegment': 'CCR'},
#   {'street': 'JERVOIS ROAD',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'project': 'PETIT JERVOIS',
#    'developer': 'Jerwyn Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 2,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 2,
#      'unitsAvail': 55}],
#    'marketSegment': 'CCR'},
#   {'street': 'RIFLE RANGE ROAD',
#    'district': '21',
#    'propertyType': 'Non-Landed',
#    'x': '22269.221392099999',
#    'project': 'MAYFAIR MODERN',
#    'y': '35543.32479689',
#    'developer': 'Citrine Property Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2118,
#      'highestPrice': 2165,
#      'lowestPrice': 1808,
#      'launchedToDate': 50,
#      'soldInMonth': 6,
#      'launchedInMonth': 0,
#      'soldToDate': 46,
#      'unitsAvail': 171}],
#    'marketSegment': 'RCR'},
#   {'street': 'RIFLE RANGE ROAD',
#    'district': '21',
#    'propertyType': 'Non-Landed',
#    'x': '22278.50422006',
#    'project': 'MAYFAIR GARDENS',
#    'y': '35614.096375559998',
#    'developer': 'Citrine Property Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1991,
#      'highestPrice': 1991,
#      'lowestPrice': 1991,
#      'launchedToDate': 180,
#      'soldInMonth': 1,
#      'launchedInMonth': 0,
#      'soldToDate': 161,
#      'unitsAvail': 215}],
#    'marketSegment': 'RCR'},
#   {'street': 'RAMBAI ROAD',
#    'district': '15',
#    'propertyType': 'Landed / Non-Landed',
#    'x': '35947.255860229997',
#    'project': 'THE RAMFORD',
#    'y': '32593.826823119998',
#    'developer': 'Centra East Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 16,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 14,
#      'unitsAvail': 16}],
#    'marketSegment': 'RCR'},
#   {'street': 'LUXUS HILL AVENUE',
#    'district': '28',
#    'propertyType': 'Landed',
#    'x': '32470.9892',
#    'project': 'LUXUS HILLS',
#    'y': '40309.9311',
#    'developer': 'Singapore United Estates Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 39}],
#    'marketSegment': 'OCR'},
#   {'street': 'MOULMEIN RISE',
#    'district': '11',
#    'propertyType': 'Non-Landed',
#    'x': '29405.165876620001',
#    'project': 'NEU AT NOVENA',
#    'y': '33564.718870649998',
#    'developer': 'RH Novena Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2585,
#      'highestPrice': 2907,
#      'lowestPrice': 2431,
#      'launchedToDate': 65,
#      'soldInMonth': 54,
#      'launchedInMonth': 65,
#      'soldToDate': 54,
#      'unitsAvail': 87}],
#    'marketSegment': 'CCR'},
#   {'street': 'LORONG LEW LIAN',
#    'district': '19',
#    'propertyType': 'Non-Landed',
#    'x': '32849.9567',
#    'project': 'FOREST WOODS',
#    'y': '37062.3916',
#    'developer': 'Serangoon Green Pte. Ltd.',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1580,
#      'highestPrice': 1580,
#      'lowestPrice': 1580,
#      'launchedToDate': 519,
#      'soldInMonth': 1,
#      'launchedInMonth': 0,
#      'soldToDate': 515,
#      'unitsAvail': 519}],
#    'marketSegment': 'OCR'},
#   {'street': 'LORONG 5 TOA PAYOH',
#    'district': '12',
#    'propertyType': 'Non-Landed',
#    'x': '29998.0108',
#    'project': 'GEM RESIDENCES',
#    'y': '35729.6428',
#    'developer': 'GEM Homes Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1909,
#      'highestPrice': 1909,
#      'lowestPrice': 1909,
#      'launchedToDate': 578,
#      'soldInMonth': 1,
#      'launchedInMonth': 0,
#      'soldToDate': 578,
#      'unitsAvail': 578}],
#    'marketSegment': 'RCR'},
#   {'street': 'MEYER PLACE',
#    'district': '15',
#    'propertyType': 'Non-Landed',
#    'x': '33893.493435440001',
#    'project': 'ONE MEYER',
#    'y': '31186.381571870001',
#    'developer': 'SL Capital (5) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2807,
#      'highestPrice': 2807,
#      'lowestPrice': 2807,
#      'launchedToDate': 66,
#      'soldInMonth': 1,
#      'launchedInMonth': 0,
#      'soldToDate': 19,
#      'unitsAvail': 66}],
#    'marketSegment': 'RCR'},
#   {'street': 'COMPASSVALE BOW',
#    'district': '19',
#    'propertyType': 'Non-Landed',
#    'project': 'SENGKANG GRAND RESIDENCES',
#    'developer': 'Siena Residential Development Pte Ltd/Siena Trustee Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 680}],
#    'marketSegment': 'OCR'},
#   {'street': 'MOHAMED SULTAN ROAD',
#    'district': '09',
#    'propertyType': 'Non-Landed',
#    'project': 'RESIDENTIAL APARTMENTS',
#    'developer': '23MSR Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 14}],
#    'marketSegment': 'CCR'},
#   {'street': 'SIMS AVENUE',
#    'district': '14',
#    'propertyType': 'Non-Landed',
#    'project': 'PARC ESTA',
#    'developer': 'MCL Land (Everbright) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1686,
#      'highestPrice': 1887,
#      'lowestPrice': 1460,
#      'launchedToDate': 950,
#      'soldInMonth': 92,
#      'launchedInMonth': 125,
#      'soldToDate': 870,
#      'unitsAvail': 1399}],
#    'marketSegment': 'RCR'},
#   {'street': 'MEYAPPA CHETTIAR ROAD',
#    'district': '13',
#    'propertyType': 'Non-Landed',
#    'x': '31778.61998761',
#    'project': 'THE ADDITION',
#    'y': '34786.634278420003',
#    'developer': 'Oxley Topaz Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1765,
#      'highestPrice': 1895,
#      'lowestPrice': 1752,
#      'launchedToDate': 26,
#      'soldInMonth': 3,
#      'launchedInMonth': 0,
#      'soldToDate': 26,
#      'unitsAvail': 26}],
#    'marketSegment': 'RCR'},
#   {'street': 'AMBER ROAD',
#    'district': '15',
#    'propertyType': 'Non-Landed',
#    'project': 'NYON',
#    'developer': 'Aurum Land Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 92,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 21,
#      'unitsAvail': 92}],
#    'marketSegment': 'RCR'},
#   {'street': 'JALAN HAJI ALIAS',
#    'district': '10',
#    'propertyType': 'Strata-Landed',
#    'x': '23750.8879',
#    'project': 'ALIAS VILLAS',
#    'y': '33935.4781',
#    'developer': 'WHA Heritage Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 6,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 6}],
#    'marketSegment': 'CCR'},
#   {'street': 'BELGRAVIA DRIVE',
#    'district': '28',
#    'propertyType': 'Strata-Landed',
#    'project': 'BELGRAVIA GREEN',
#    'developer': 'Fairview Developments Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 889,
#      'highestPrice': 891,
#      'lowestPrice': 881,
#      'launchedToDate': 81,
#      'soldInMonth': 5,
#      'launchedInMonth': 0,
#      'soldToDate': 78,
#      'unitsAvail': 81}],
#    'marketSegment': 'OCR'},
#   {'street': 'DERBYSHIRE ROAD',
#    'district': '11',
#    'propertyType': 'Non-Landed',
#    'x': '29386.24216108',
#    'project': 'FYVE DERBYSHIRE',
#    'y': '33167.649105350003',
#    'developer': 'RH Developments Two Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2390,
#      'highestPrice': 2496,
#      'lowestPrice': 2284,
#      'launchedToDate': 36,
#      'soldInMonth': 2,
#      'launchedInMonth': 0,
#      'soldToDate': 18,
#      'unitsAvail': 71}],
#    'marketSegment': 'CCR'},
#   {'street': 'PONGGOL SEVENTEENTH AVENUE',
#    'district': '19',
#    'propertyType': 'Strata-Landed',
#    'x': '35725.9428',
#    'project': 'WHITE COVE',
#    'y': '44039.6095',
#    'developer': 'Tai Lai Holdings Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 17}],
#    'marketSegment': 'OCR'},
#   {'street': 'CLUNY PARK ROAD',
#    'district': '10',
#    'propertyType': 'Strata-Landed',
#    'project': 'BOTANIC @ CLUNY PARK',
#    'developer': 'Cluny Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 6,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 3,
#      'unitsAvail': 6}],
#    'marketSegment': 'CCR'},
#   {'street': 'AMBER GARDENS',
#    'district': '15',
#    'propertyType': 'Non-Landed',
#    'project': 'AMBER SEA',
#    'developer': 'Urban Park Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 132}],
#    'marketSegment': 'RCR'},
#   {'street': 'JALAN KEMAMAN',
#    'district': '12',
#    'propertyType': 'Non-Landed',
#    'project': 'VERTICUS',
#    'developer': 'SB (Kemaman) Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 162}],
#    'marketSegment': 'RCR'},
#   {'street': 'DUNDEE ROAD',
#    'district': '03',
#    'propertyType': 'Non-Landed',
#    'x': '25080.6561',
#    'project': 'QUEENS PEAK',
#    'y': '30754.7572',
#    'developer': 'HY Realty (Dundee) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1715,
#      'highestPrice': 1715,
#      'lowestPrice': 1715,
#      'launchedToDate': 736,
#      'soldInMonth': 1,
#      'launchedInMonth': 0,
#      'soldToDate': 705,
#      'unitsAvail': 736}],
#    'marketSegment': 'RCR'},
#   {'street': 'JALAN EUNOS',
#    'district': '14',
#    'propertyType': 'Non-Landed',
#    'x': '36087.122230580003',
#    'project': 'URBAN TREASURES',
#    'y': '34737.676861419999',
#    'developer': 'Fragrance Treasures Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 237}],
#    'marketSegment': 'OCR'},
#   {'street': 'NIM RISE/NIM TERRACE',
#    'district': '28',
#    'propertyType': 'Landed',
#    'project': 'NIM COLLECTION',
#    'developer': 'Singapore United Estates Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1744,
#      'highestPrice': 1744,
#      'lowestPrice': 1744,
#      'launchedToDate': 98,
#      'soldInMonth': 1,
#      'launchedInMonth': 0,
#      'soldToDate': 82,
#      'unitsAvail': 98}],
#    'marketSegment': 'OCR'},
#   {'street': 'UPPER CHANGI ROAD NORTH',
#    'district': '17',
#    'propertyType': 'Non-Landed',
#    'x': '43256.302401219996',
#    'project': 'PARC KOMO',
#    'y': '38088.560310110001',
#    'developer': 'CEL Real Estate Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1510,
#      'highestPrice': 1570,
#      'lowestPrice': 1449,
#      'launchedToDate': 276,
#      'soldInMonth': 3,
#      'launchedInMonth': 0,
#      'soldToDate': 108,
#      'unitsAvail': 276}],
#    'marketSegment': 'OCR'},
#   {'street': 'TELOK KURAU ROAD',
#    'district': '15',
#    'propertyType': 'Non-Landed',
#    'x': '36629.723625620003',
#    'project': 'RESIDENCE TWENTY-TWO',
#    'y': '32587.910429869999',
#    'developer': 'Grow99 Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 22,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 1,
#      'unitsAvail': 22}],
#    'marketSegment': 'OCR'},
#   {'street': 'HOW SUN DRIVE',
#    'district': '19',
#    'propertyType': 'Non-Landed',
#    'x': '33048.884646669997',
#    'project': 'THE GAZANIA',
#    'y': '36335.024184450003',
#    'developer': 'Singhaiyi Huajiang Sun Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 125,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 24,
#      'unitsAvail': 250}],
#    'marketSegment': 'OCR'},
#   {'street': 'CASHEW ROAD',
#    'district': '23',
#    'propertyType': 'Landed',
#    'project': 'CASHEW GREEN',
#    'developer': 'Lucky Realty Co Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 11,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 6,
#      'unitsAvail': 19}],
#    'marketSegment': 'OCR'},
#   {'street': 'SUMANG WALK',
#    'district': '19',
#    'propertyType': 'Exec Condo',
#    'project': 'PIERMONT GRAND',
#    'developer': 'Pavo Properties Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1069,
#      'highestPrice': 1146,
#      'lowestPrice': 927,
#      'launchedToDate': 820,
#      'soldInMonth': 26,
#      'launchedInMonth': 0,
#      'soldToDate': 436,
#      'unitsAvail': 820}],
#    'marketSegment': 'OCR'},
#   {'street': 'CHONG KUO ROAD',
#    'district': '26',
#    'propertyType': 'Non-Landed',
#    'project': 'THE ESSENCE',
#    'developer': 'Chong Kuo Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1410,
#      'highestPrice': 1423,
#      'lowestPrice': 1297,
#      'launchedToDate': 84,
#      'soldInMonth': 5,
#      'launchedInMonth': 0,
#      'soldToDate': 23,
#      'unitsAvail': 84}],
#    'marketSegment': 'OCR'},
#   {'street': 'JERVOIS ROAD',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'project': 'JERVOIS PRIVE',
#    'developer': 'Jervois Midas Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 43}],
#    'marketSegment': 'CCR'},
#   {'street': 'LORONG N TELOK KURAU',
#    'district': '15',
#    'propertyType': 'Strata-Landed',
#    'x': '36649.9616',
#    'project': 'TK ONE',
#    'y': '32487.7655',
#    'developer': 'Longfor Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 5,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 5}],
#    'marketSegment': 'OCR'},
#   {'street': 'EVELYN ROAD',
#    'district': '11',
#    'propertyType': 'Non-Landed',
#    'project': '10 EVELYN',
#    'developer': 'Creative Investments Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 56,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 4,
#      'unitsAvail': 56}],
#    'marketSegment': 'CCR'},
#   {'street': 'LORONG 1 REALTY PARK',
#    'district': '19',
#    'propertyType': 'Strata-Landed',
#    'project': 'PARKWOOD COLLECTION',
#    'developer': 'Fantasia (Park) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 13,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 53}],
#    'marketSegment': 'OCR'},
#   {'street': 'SERANGOON NORTH AVENUE 1',
#    'district': '19',
#    'propertyType': 'Non-Landed',
#    'project': 'AFFINITY AT SERANGOON',
#    'developer': 'Oxley Serangoon Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1472,
#      'highestPrice': 1616,
#      'lowestPrice': 1369,
#      'launchedToDate': 700,
#      'soldInMonth': 27,
#      'launchedInMonth': 50,
#      'soldToDate': 614,
#      'unitsAvail': 1052}],
#    'marketSegment': 'OCR'},
#   {'street': 'YIO CHU KANG ROAD',
#    'district': '19',
#    'propertyType': 'Non-Landed',
#    'project': 'PARKWOOD RESIDENCES',
#    'developer': 'Oxley Garnet Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 18}],
#    'marketSegment': 'OCR'},
#   {'street': 'HOUGANG AVENUE 7',
#    'district': '19',
#    'propertyType': 'Non-Landed',
#    'project': 'RIVERFRONT RESIDENCES',
#    'developer': 'Rio Casa Venture Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1337,
#      'highestPrice': 1441,
#      'lowestPrice': 1203,
#      'launchedToDate': 1200,
#      'soldInMonth': 43,
#      'launchedInMonth': 0,
#      'soldToDate': 1176,
#      'unitsAvail': 1472}],
#    'marketSegment': 'OCR'},
#   {'street': 'MENG SUAN ROAD',
#    'district': '26',
#    'propertyType': 'Landed',
#    'x': '25744.731378189999',
#    'project': 'LANDED HOUSING DEVELOPMENT',
#    'y': '42805.785781769999',
#    'developer': 'Meng Suan Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 9,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 4,
#      'unitsAvail': 9}],
#    'marketSegment': 'OCR'},
#   {'street': 'AMBER GARDENS',
#    'district': '15',
#    'propertyType': 'Non-Landed',
#    'project': 'AMBER PARK',
#    'developer': 'Aquarius Properties Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2443,
#      'highestPrice': 2510,
#      'lowestPrice': 2316,
#      'launchedToDate': 200,
#      'soldInMonth': 10,
#      'launchedInMonth': 20,
#      'soldToDate': 186,
#      'unitsAvail': 592}],
#    'marketSegment': 'RCR'},
#   {'street': 'SUNRISE TERRACE',
#    'district': '28',
#    'propertyType': 'Strata-Landed',
#    'x': '30456.9191',
#    'project': 'ALANA',
#    'y': '41215.3534',
#    'developer': 'Bullion Holdings Pte Ltd & Cabana JV Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 26,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 24,
#      'unitsAvail': 78}],
#    'marketSegment': 'OCR'},
#   {'street': 'SOUTH BUONA VISTA ROAD',
#    'district': '05',
#    'propertyType': 'Non-Landed',
#    'project': 'KENT RIDGE HILL RESIDENCES',
#    'developer': 'Oxley Spinel Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1774,
#      'highestPrice': 1862,
#      'lowestPrice': 1488,
#      'launchedToDate': 300,
#      'soldInMonth': 17,
#      'launchedInMonth': 0,
#      'soldToDate': 261,
#      'unitsAvail': 548}],
#    'marketSegment': 'RCR'},
#   {'street': 'SERANGOON NORTH VIEW',
#    'district': '19',
#    'propertyType': 'Non-Landed',
#    'project': 'THE GARDEN RESIDENCES',
#    'developer': 'Gardens Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1535,
#      'highestPrice': 1644,
#      'lowestPrice': 1462,
#      'launchedToDate': 263,
#      'soldInMonth': 16,
#      'launchedInMonth': 33,
#      'soldToDate': 219,
#      'unitsAvail': 613}],
#    'marketSegment': 'OCR'},
#   {'street': 'UPPER EAST COAST ROAD',
#    'district': '15',
#    'propertyType': 'Non-Landed',
#    'project': '77 @ EAST COAST',
#    'developer': 'KDC (77) Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 41}],
#    'marketSegment': 'OCR'},
#   {'street': 'BEACH ROAD',
#    'district': '07',
#    'propertyType': 'Non-Landed',
#    'project': 'MIDTOWN BAY',
#    'developer': 'Guoco Midtown Pte Ltd/Midtown Bay Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2900,
#      'highestPrice': 3804,
#      'lowestPrice': 2438,
#      'launchedToDate': 50,
#      'soldInMonth': 48,
#      'launchedInMonth': 50,
#      'soldToDate': 48,
#      'unitsAvail': 219}],
#    'marketSegment': 'CCR'},
#   {'street': 'EWE BOON ROAD',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'project': 'JUNIPER HILL',
#    'developer': 'Allgreen Properties Limited',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 52,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 10,
#      'unitsAvail': 115}],
#    'marketSegment': 'CCR'},
#   {'street': 'JALAN ARNAP/ONE TREE HILL/JALAN KELAWAR',
#    'district': '10',
#    'propertyType': 'Landed',
#    'project': 'ONE TREE HILL COLLECTION',
#    'developer': 'Lum Chang Auriga Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 4,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 3,
#      'unitsAvail': 14}],
#    'marketSegment': 'CCR'},
#   {'street': 'ANAMALAI AVENUE',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'project': 'ROYALGREEN',
#    'developer': 'Sky Top Investments Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2741,
#      'highestPrice': 2883,
#      'lowestPrice': 2612,
#      'launchedToDate': 108,
#      'soldInMonth': 42,
#      'launchedInMonth': 108,
#      'soldToDate': 42,
#      'unitsAvail': 285}],
#    'marketSegment': 'CCR'},
#   {'street': 'GREENLEAF ROAD',
#    'district': '10',
#    'propertyType': 'Landed',
#    'x': '22819.3893',
#    'project': 'LINK RESIDENCE @ HOLLAND',
#    'y': '33788.8233',
# ...
#      'unitsAvail': 39}],
#    'marketSegment': 'CCR'},
#   {'street': 'BALMEG HILL',
#    'district': '05',
#    'propertyType': 'Non-Landed',
#    'project': 'SUNSTONE HILL',
#    'developer': 'Sunstone Properties (Pasir Panjang) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 28}],
#    'marketSegment': 'RCR'},
#   {'street': 'LORONG KISMIS',
#    'district': '21',
#    'propertyType': 'Non-Landed',
#    'x': '20872.738767059999',
#    'project': 'VIEW AT KISMIS',
#    'y': '35571.356772800002',
#    'developer': 'Roxy-TE2 Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1694,
#      'highestPrice': 1789,
#      'lowestPrice': 1600,
#      'launchedToDate': 80,
#      'soldInMonth': 11,
#      'launchedInMonth': 0,
#      'soldToDate': 47,
#      'unitsAvail': 186}],
#    'marketSegment': 'RCR'},
#   {'street': 'LEONIE HILL',
#    'district': '09',
#    'propertyType': 'Non-Landed',
#    'x': '27909.710139860001',
#    'project': 'FERRA',
#    'y': '31321.084215810001',
#    'developer': 'Orchard Landmark Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 104}],
#    'marketSegment': 'CCR'},
#   {'street': 'MEYER ROAD',
#    'district': '15',
#    'propertyType': 'Non-Landed',
#    'x': '34731.874658950003',
#    'project': 'MEYERHOUSE',
#    'y': '31172.953524140002',
#    'developer': 'Secure Venture Development (N0.1) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 15,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 5,
#      'unitsAvail': 56}],
#    'marketSegment': 'RCR'},
#   {'street': 'GUILLEMARD CRESCENT',
#    'district': '14',
#    'propertyType': 'Non-Landed',
#    'project': 'ARENA RESIDENCES',
#    'developer': 'RH Guillemard Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1868,
#      'highestPrice': 1878,
#      'lowestPrice': 1858,
#      'launchedToDate': 70,
#      'soldInMonth': 2,
#      'launchedInMonth': 0,
#      'soldToDate': 67,
#      'unitsAvail': 98}],
#    'marketSegment': 'RCR'},
#   {'street': 'WAK HASSAN DRIVE',
#    'district': '27',
#    'propertyType': 'Strata-Landed',
#    'x': '28662.06381303',
#    'project': 'WATERCOVE',
#    'y': '49233.372997440003',
#    'developer': 'Sembawang Estates (Pte) Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 715,
#      'highestPrice': 715,
#      'lowestPrice': 715,
#      'launchedToDate': 80,
#      'soldInMonth': 1,
#      'launchedInMonth': 0,
#      'soldToDate': 79,
#      'unitsAvail': 80}],
#    'marketSegment': 'OCR'},
#   {'street': 'ANCHORVALE LANE',
#    'district': '19',
#    'propertyType': 'Exec Condo',
#    'project': 'RIVERCOVE RESIDENCES',
#    'developer': 'Hoi Hup Sunway Sengkang Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 628,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 625,
#      'unitsAvail': 628}],
#    'marketSegment': 'OCR'},
#   {'street': 'GRANGE ROAD',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'x': '27144.33328099',
#    'project': '120 GRANGE',
#    'y': '31375.71455257',
#    'developer': 'RH Orchard Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 3234,
#      'highestPrice': 3234,
#      'lowestPrice': 3234,
#      'launchedToDate': 50,
#      'soldInMonth': 1,
#      'launchedInMonth': 0,
#      'soldToDate': 46,
#      'unitsAvail': 56}],
#    'marketSegment': 'CCR'},
#   {'street': 'SERANGOON ROAD',
#    'district': '12',
#    'propertyType': 'Non-Landed',
#    'x': '31654.44299275',
#    'project': 'JUI RESIDENCES',
#    'y': '34299.875639040003',
#    'developer': 'Tiara Land Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1793,
#      'highestPrice': 1825,
#      'lowestPrice': 1676,
#      'launchedToDate': 117,
#      'soldInMonth': 5,
#      'launchedInMonth': 0,
#      'soldToDate': 69,
#      'unitsAvail': 117}],
#    'marketSegment': 'RCR'},
#   {'street': 'DRAYCOTT PARK',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'x': '27705.684730290001',
#    'project': 'ONE DRAYCOTT',
#    'y': '32493.294249200001',
#    'developer': 'Champsworth Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 64,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 3,
#      'unitsAvail': 64}],
#    'marketSegment': 'CCR'},
#   {'street': 'RIVER VALLEY CLOSE',
#    'district': '09',
#    'propertyType': 'Non-Landed',
#    'project': 'THE AVENIR',
#    'developer': 'Carmel Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 376}],
#    'marketSegment': 'CCR'},
#   {'street': 'GRANGE ROAD',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'project': 'GRANGE 1866',
#    'developer': 'Grange 1866 Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 60}],
#    'marketSegment': 'CCR'},
#   {'street': 'JERVOIS ROAD',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'x': '26829.549665819999',
#    'project': '38 JERVOIS',
#    'y': '30709.044900410002',
#    'developer': 'Prominent @ Jervois Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 27,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 11,
#      'unitsAvail': 27}],
#    'marketSegment': 'CCR'},
#   {'street': 'TAMPINES STREET 86',
#    'district': '18',
#    'propertyType': 'Non-Landed',
#    'project': 'THE TAPESTRY',
#    'developer': 'Bellevue Properties Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1294,
#      'highestPrice': 1498,
#      'lowestPrice': 1242,
#      'launchedToDate': 750,
#      'soldInMonth': 15,
#      'launchedInMonth': 0,
#      'soldToDate': 675,
#      'unitsAvail': 861}],
#    'marketSegment': 'OCR'},
#   {'street': 'DUNEARN ROAD',
#    'district': '11',
#    'propertyType': 'Non-Landed',
#    'x': '28643.688',
#    'project': 'PULLMAN RESIDENCES, NEWTON',
#    'y': '32965.6961',
#    'developer': 'EL Development (Horizon) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 340}],
#    'marketSegment': 'CCR'},
#   {'street': 'AMBER ROAD',
#    'district': '15',
#    'propertyType': 'Non-Landed',
#    'x': '35635.450328580001',
#    'project': 'AMBER 45',
#    'y': '31683.037938530002',
#    'developer': 'UOL Development (Amber) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 120,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 111,
#      'unitsAvail': 139}],
#    'marketSegment': 'RCR'},
#   {'street': 'SHUNFU ROAD',
#    'district': '20',
#    'propertyType': 'Non-Landed',
#    'project': 'JADESCAPE',
#    'developer': 'Qingjian Realty (Marymount) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1702,
#      'highestPrice': 1808,
#      'lowestPrice': 1599,
#      'launchedToDate': 600,
#      'soldInMonth': 13,
#      'launchedInMonth': 0,
#      'soldToDate': 482,
#      'unitsAvail': 1206}],
#    'marketSegment': 'RCR'},
#   {'street': 'HOLLAND ROAD',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'x': '24184.20081998',
#    'project': 'THE ENCLAVE . HOLLAND',
#    'y': '32717.6761026',
#    'developer': 'Three Sixty-Nine Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 10,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 10,
#      'unitsAvail': 26}],
#    'marketSegment': 'CCR'},
#   {'street': 'ORCHARD BOULEVARD',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'project': 'BOULEVARD 88',
#    'developer': 'Granmil Holdings Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 3611,
#      'highestPrice': 3805,
#      'lowestPrice': 3296,
#      'launchedToDate': 90,
#      'soldInMonth': 6,
#      'launchedInMonth': 10,
#      'soldToDate': 82,
#      'unitsAvail': 154}],
#    'marketSegment': 'CCR'},
#   {'street': 'PASIR PANJANG ROAD',
#    'district': '05',
#    'propertyType': 'Non-Landed',
#    'x': '22433.04128066',
#    'project': 'SEASUITES',
#    'y': '29434.351824919999',
#    'developer': 'Link (THM) Greenleaf Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 52,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 50,
#      'unitsAvail': 52}],
#    'marketSegment': 'RCR'},
#   {'street': 'STIRLING ROAD',
#    'district': '03',
#    'propertyType': 'Non-Landed',
#    'project': 'STIRLING RESIDENCES',
#    'developer': 'LN Development (Stirling) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1848,
#      'highestPrice': 2132,
#      'lowestPrice': 1730,
#      'launchedToDate': 980,
#      'soldInMonth': 45,
#      'launchedInMonth': 150,
#      'soldToDate': 871,
#      'unitsAvail': 1259}],
#    'marketSegment': 'RCR'},
#   {'street': 'KAMPONG BAHRU ROAD',
#    'district': '04',
#    'propertyType': 'Non-Landed',
#    'x': '27325.27521875',
#    'project': 'PERMAI RESIDENCES',
#    'y': '28276.555615409999',
#    'developer': 'Popular Land Investment Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 0,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 0,
#      'unitsAvail': 17}],
#    'marketSegment': 'RCR'},
#   {'street': 'POTONG PASIR AVENUE 1',
#    'district': '13',
#    'propertyType': 'Non-Landed',
#    'project': 'THE TRE VER',
#    'developer': 'UVD (Projects) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1632,
#      'highestPrice': 1686,
#      'lowestPrice': 1504,
#      'launchedToDate': 650,
#      'soldInMonth': 14,
#      'launchedInMonth': 0,
#      'soldToDate': 617,
#      'unitsAvail': 729}],
#    'marketSegment': 'RCR'},
#   {'street': 'HOLLAND GROVE ROAD',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'x': '22385.84169562',
#    'project': 'PARKSUITES',
#    'y': '33249.43690999',
#    'developer': 'Kentish View Pte Ltd/Lucky Pinnacle Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 50,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 20,
#      'unitsAvail': 119}],
#    'marketSegment': 'CCR'},
#   {'street': 'CUSCADEN WALK',
#    'district': '10',
#    'propertyType': 'Non-Landed',
#    'x': '27571.019145600001',
#    'project': '3 CUSCADEN',
#    'y': '31822.377366920001',
#    'developer': 'SL Capital (2) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 3572,
#      'highestPrice': 3921,
#      'lowestPrice': 3278,
#      'launchedToDate': 96,
#      'soldInMonth': 5,
#      'launchedInMonth': 0,
#      'soldToDate': 79,
#      'unitsAvail': 96}],
#    'marketSegment': 'CCR'},
#   {'street': 'JALAN LOYANG BESAR',
#    'district': '17',
#    'propertyType': 'Non-Landed',
#    'project': 'CASA AL MARE',
#    'developer': 'SL Capital (4) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 49,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 12,
#      'unitsAvail': 49}],
#    'marketSegment': 'OCR'},
#   {'street': 'UPPER BUKIT TIMAH ROAD',
#    'district': '23',
#    'propertyType': 'Non-Landed',
#    'x': '20181.165862530002',
#    'project': 'BUKIT 828',
#    'y': '39525.506924689997',
#    'developer': 'RH Capital Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1597,
#      'highestPrice': 1607,
#      'lowestPrice': 1462,
#      'launchedToDate': 17,
#      'soldInMonth': 5,
#      'launchedInMonth': 0,
#      'soldToDate': 15,
#      'unitsAvail': 34}],
#    'marketSegment': 'OCR'},
#   {'street': 'HULLET ROAD',
#    'district': '09',
#    'propertyType': 'Non-Landed',
#    'x': '28609.3276881',
#    'project': '8 HULLET',
#    'y': '31708.596722709999',
#    'developer': 'Hullet Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 44,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 37,
#      'unitsAvail': 44}],
#    'marketSegment': 'CCR'},
#   {'street': 'JALAN REMAJA',
#    'district': '23',
#    'propertyType': 'Non-Landed',
#    'project': 'MONT BOTANIK RESIDENCE',
#    'developer': 'Episcia Land Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1664,
#      'highestPrice': 1721,
#      'lowestPrice': 1602,
#      'launchedToDate': 54,
#      'soldInMonth': 19,
#      'launchedInMonth': 0,
#      'soldToDate': 37,
#      'unitsAvail': 108}],
#    'marketSegment': 'OCR'},
#   {'street': 'MARGARET DRIVE',
#    'district': '03',
#    'propertyType': 'Non-Landed',
#    'project': 'MARGARET VILLE',
#    'developer': 'MCL Land (Regency) Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1919,
#      'highestPrice': 2119,
#      'lowestPrice': 1748,
#      'launchedToDate': 309,
#      'soldInMonth': 8,
#      'launchedInMonth': 31,
#      'soldToDate': 266,
#      'unitsAvail': 309}],
#    'marketSegment': 'RCR'},
#   {'street': 'JALAN MAT JAMBOL',
#    'district': '05',
#    'propertyType': 'Non-Landed',
#    'x': '23366.6919',
#    'project': 'BIJOU',
#    'y': '28819.132',
#    'developer': 'JU-I Properties Pte. Ltd.',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 2053,
#      'highestPrice': 2053,
#      'lowestPrice': 2053,
#      'launchedToDate': 120,
#      'soldInMonth': 1,
#      'launchedInMonth': 0,
#      'soldToDate': 85,
#      'unitsAvail': 120}],
#    'marketSegment': 'RCR'},
#   {'street': 'LORONG 24 GEYLANG',
#    'district': '14',
#    'propertyType': 'Non-Landed',
#    'x': '33596.102744579997',
#    'project': 'THE OCTET',
#    'y': '32713.618357060001',
#    'developer': 'Osmo Capital Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 0,
#      'highestPrice': 0,
#      'lowestPrice': 0,
#      'launchedToDate': 56,
#      'soldInMonth': 0,
#      'launchedInMonth': 0,
#      'soldToDate': 56,
#      'unitsAvail': 56}],
#    'marketSegment': 'RCR'},
#   {'street': 'BIDADARI PARK DRIVE',
#    'district': '13',
#    'propertyType': 'Non-Landed',
#    'project': 'THE WOODLEIGH RESIDENCES',
#    'developer': 'The Woodleigh Mall Pte Ltd/The Woodleigh Residences Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1864,
#      'highestPrice': 1984,
#      'lowestPrice': 1791,
#      'launchedToDate': 325,
#      'soldInMonth': 19,
#      'launchedInMonth': 0,
#      'soldToDate': 163,
#      'unitsAvail': 667}],
#    'marketSegment': 'RCR'},
#   {'street': 'WOODLEIGH LANE',
#    'district': '13',
#    'propertyType': 'Non-Landed',
#    'project': 'PARK COLONIAL',
#    'developer': 'CEL Unique Development Pte Ltd',
#    'developerSales': [{'refPeriod': '1019',
#      'medianPrice': 1767,
#      'highestPrice': 1964,
#      'lowestPrice': 1635,
#      'launchedToDate': 805,
#      'soldInMonth': 9,
#      'launchedInMonth': 0,
#      'soldToDate': 698,
#      'unitsAvail': 805}],
#    'marketSegment': 'RCR'}]}
