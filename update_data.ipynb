# %%
from datetime import datetime, timedelta
import calendar
import requests
import pandas as pd
from time import sleep

# %%
df = pd.read_csv('data/apartments_condos/total.csv')
# filtered_df = df[df['']]
df.sort_values(['date_of_sale', 'unit_price_psf', 'price'], ascending=[False, True, True])
# Out:
#                   project_name                street_name         type  \
# 50252           REGENT HEIGHTS  BUKIT BATOK EAST AVENUE 5  Condominium
# 50253               MAYSPRINGS                 PETIR ROAD    Apartment
# 50254  CASHEW PARK CONDOMINIUM                CASHEW ROAD  Condominium
# 32713             CHANGI GREEN     UPPER CHANGI ROAD EAST  Condominium
# 47654             SOUTHAVEN II              HINDHEDE WALK  Condominium
# ...                        ...                        ...          ...
# 15431           OUE TWIN PEAKS           LEONIE HILL ROAD  Condominium
# 15445                 HILLTOPS           CAIRNHILL CIRCLE  Condominium
# 15440           OUE TWIN PEAKS           LEONIE HILL ROAD  Condominium
# 15413   THE ORCHARD RESIDENCES          ORCHARD BOULEVARD    Apartment
# 18920        LE NOUVEL ARDMORE               ARDMORE PARK  Condominium
#
#        postal_district market_segment                              tenure  \
# 50252               23            OCR   99 yrs lease commencing from 1995
# 50253               23            OCR   99 yrs lease commencing from 1994
# 50254               23            OCR  999 yrs lease commencing from 1882
# 32713               16            OCR                            Freehold
# 47654               21            OCR  999 yrs lease commencing from 1877
# ...                ...            ...                                 ...
# 15431                9            CCR   99 yrs lease commencing from 2010
# 15445                9            CCR                            Freehold
# 15440                9            CCR   99 yrs lease commencing from 2010
# 15413                9            CCR   99 yrs lease commencing from 2006
# 18920               10            CCR                            Freehold
#
#       type_of_sale  num_units     price nett_price  area_sqft type_of_area  \
# 50252       Resale          1    795000          -       1023       Strata
# 50253       Resale          1   1250000          -       1550       Strata
# 50254       Resale          1   1900000          -       1819       Strata
# 32713       Resale          1    945000          -        872       Strata
# 47654       Resale          1   1580000          -       1442       Strata
# ...            ...        ...       ...        ...        ...          ...
# 15431       Resale          1   4865000          -       1604       Strata
# 15445       Resale          1   3977000          -       1249       Strata
# 15440       Resale          1   1855800          -        570       Strata
# 15413       Resale          1   7400000          -       2174       Strata
# 18920       Resale          1  15174945          -       3789       Strata
#
#       floor_level  unit_price_psf date_of_sale
# 50252    11 to 15             777   2020-03-31
# 50253    21 to 25             806   2020-03-31
# 50254    06 to 10            1044   2020-03-31
# 32713    01 to 05            1084   2020-03-31
# 47654    01 to 05            1095   2020-03-31
# ...           ...             ...          ...
# 15431    26 to 30            3033   2017-03-31
# 15445    16 to 20            3185   2017-03-31
# 15440    21 to 25            3253   2017-03-31
# 15413    46 to 50            3403   2017-03-31
# 18920    21 to 25            4005   2017-03-31
#
# [55765 rows x 15 columns]
